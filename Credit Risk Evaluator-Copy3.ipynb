# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression

# %%
# Given DataFrames
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
#test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
# Read the 2019 training csv file into a pandas dataFrame
train_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# inspect the training DataFrame
pd.set_option('display.max_columns', 95)
train_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70       MORTGAGE
# 1       25429  25429     6000.0    0.1524       208.70           RENT
# 2       38496  38496     3600.0    0.1695       128.27           RENT
# 3       19667  19667    20000.0    0.1524       478.33           RENT
# 4       37505  37505     3600.0    0.1240       120.27           RENT
#
#    annual_inc verification_status loan_status pymnt_plan    dti  delinq_2yrs  \
# 0    140000.0        Not Verified    low_risk          n  19.75          0.0
# 1     55000.0        Not Verified    low_risk          n  11.52          2.0
# 2     42000.0        Not Verified    low_risk          n   6.74          0.0
# 3    100000.0        Not Verified    low_risk          n  12.13          0.0
# 4     50000.0        Not Verified    low_risk          n  16.08          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  total_acc  \
# ...

# %%
# confirm inspection of training dataframe
train_df.dtypes
# Out:
# Unnamed: 0                      int64
# index                           int64
# loan_amnt                     float64
# int_rate                      float64
# installment                   float64
#                                ...
# total_bal_ex_mort             float64
# total_bc_limit                float64
# total_il_high_credit_limit    float64
# hardship_flag                  object
# debt_settlement_flag           object
# Length: 86, dtype: object

# %%
# confirm inspection of training dataframe
# train_df.dtypes

# %%
# drop rows with missing data
train_df = train_df.dropna()
train_df
# Out:
#       Unnamed: 0  index  loan_amnt  int_rate  installment home_ownership  \
# 0          67991  67991    40000.0    0.0819       814.70       MORTGAGE
# 1          25429  25429     6000.0    0.1524       208.70           RENT
# 2          38496  38496     3600.0    0.1695       128.27           RENT
# 3          19667  19667    20000.0    0.1524       478.33           RENT
# 4          37505  37505     3600.0    0.1240       120.27           RENT
# ...          ...    ...        ...       ...          ...            ...
# 4697       77282  77282    30000.0    0.1240       673.42           RENT
# 4698       77291  77291    24000.0    0.0756       747.22           RENT
# 4699       77292  77292    10000.0    0.2305       387.36           RENT
# 4700       77297  77297     8000.0    0.1862       205.86           RENT
# 4701       77304  77304    30000.0    0.2055      1123.34           RENT
#
#       annual_inc verification_status loan_status pymnt_plan    dti  \
# ...

# %%
# drop columns with missing data
train_df = train_df.dropna(axis='columns')
train_df
# Out:
#       Unnamed: 0  index  loan_amnt  int_rate  installment home_ownership  \
# 0          67991  67991    40000.0    0.0819       814.70       MORTGAGE
# 1          25429  25429     6000.0    0.1524       208.70           RENT
# 2          38496  38496     3600.0    0.1695       128.27           RENT
# 3          19667  19667    20000.0    0.1524       478.33           RENT
# 4          37505  37505     3600.0    0.1240       120.27           RENT
# ...          ...    ...        ...       ...          ...            ...
# 4697       77282  77282    30000.0    0.1240       673.42           RENT
# 4698       77291  77291    24000.0    0.0756       747.22           RENT
# 4699       77292  77292    10000.0    0.2305       387.36           RENT
# 4700       77297  77297     8000.0    0.1862       205.86           RENT
# 4701       77304  77304    30000.0    0.2055      1123.34           RENT
#
#       annual_inc verification_status loan_status pymnt_plan    dti  \
# ...

# %%
# the 'unnamed 0'index 0 and the name 'index' columns appear to be the same, one needs to go
train_df = train_df.drop(columns=["Unnamed: 0"])
train_df
# Out:
#       index  loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0     67991    40000.0    0.0819       814.70       MORTGAGE    140000.0
# 1     25429     6000.0    0.1524       208.70           RENT     55000.0
# 2     38496     3600.0    0.1695       128.27           RENT     42000.0
# 3     19667    20000.0    0.1524       478.33           RENT    100000.0
# 4     37505     3600.0    0.1240       120.27           RENT     50000.0
# ...     ...        ...       ...          ...            ...         ...
# 4697  77282    30000.0    0.1240       673.42           RENT    140480.0
# 4698  77291    24000.0    0.0756       747.22           RENT     50000.0
# 4699  77292    10000.0    0.2305       387.36           RENT     33000.0
# 4700  77297     8000.0    0.1862       205.86           RENT     38000.0
# 4701  77304    30000.0    0.2055      1123.34           RENT    180000.0
#
#      verification_status loan_status pymnt_plan    dti  delinq_2yrs  \
# ...

# %%
# might as well make the index the 'index' column
train_df = train_df.set_index("index")
train_df
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# index
# 67991    40000.0    0.0819       814.70       MORTGAGE    140000.0
# 25429     6000.0    0.1524       208.70           RENT     55000.0
# 38496     3600.0    0.1695       128.27           RENT     42000.0
# 19667    20000.0    0.1524       478.33           RENT    100000.0
# 37505     3600.0    0.1240       120.27           RENT     50000.0
# ...          ...       ...          ...            ...         ...
# 77282    30000.0    0.1240       673.42           RENT    140480.0
# 77291    24000.0    0.0756       747.22           RENT     50000.0
# 77292    10000.0    0.2305       387.36           RENT     33000.0
# 77297     8000.0    0.1862       205.86           RENT     38000.0
# 77304    30000.0    0.2055      1123.34           RENT    180000.0
#
#       verification_status loan_status pymnt_plan    dti  delinq_2yrs  \
# index
# 67991        Not Verified    low_risk          n  19.75          0.0
# ...

# %%
# column names
train_df.columns
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'home_ownership', 'annual_inc',
#        'verification_status', 'loan_status', 'pymnt_plan', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'initial_list_status', 'out_prncp', 'out_prncp_inv',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal',
#        'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m',
#        'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m',
#        'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi',
#        'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal',
#        'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'delinq_amnt',
# ...

# %% [markdown]
# ### might need to convert these columns later, need to inspect first to make sure boolean
#
# home_ownership
#
# verification_status
#
# loan_status
#
# pymnt_plan
#
# initial_list_status
#
# application_type
#
# hardship_flag
#
# debt_settlement_flag

# %%
list(train_df['home_ownership'].unique())
# Out:
# ['MORTGAGE', 'RENT', 'OWN', 'ANY']

# %%
# encode string values to numeric values
ownership_dict = {'MORTGAGE': 0, 'RENT': 1, 'OWN': 2, 'ANY': 3}
trained_df1 = train_df.replace({'home_ownership': ownership_dict})
trained_df1.head()
# Out:
#        loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# index
# 67991    40000.0    0.0819       814.70               0    140000.0
# 25429     6000.0    0.1524       208.70               1     55000.0
# 38496     3600.0    0.1695       128.27               1     42000.0
# 19667    20000.0    0.1524       478.33               1    100000.0
# 37505     3600.0    0.1240       120.27               1     50000.0
#
#       verification_status loan_status pymnt_plan    dti  delinq_2yrs  \
# index
# 67991        Not Verified    low_risk          n  19.75          0.0
# 25429        Not Verified    low_risk          n  11.52          2.0
# 38496        Not Verified    low_risk          n   6.74          0.0
# 19667        Not Verified    low_risk          n  12.13          0.0
# 37505        Not Verified    low_risk          n  16.08          0.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  total_acc  \
# index
# ...

# %%
list(trained_df1['verification_status'].unique())
# Out:
# ['Not Verified', 'Verified', 'Source Verified']

# %%
# encode string values to numeric values
verification_dict = {'Not Verified': 0, 'Source Verified': 1, 'Verified': 2}
trained_df2 = trained_df1.replace({'verification_status': verification_dict})
trained_df2.head()
# Out:
#        loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# index
# 67991    40000.0    0.0819       814.70               0    140000.0
# 25429     6000.0    0.1524       208.70               1     55000.0
# 38496     3600.0    0.1695       128.27               1     42000.0
# 19667    20000.0    0.1524       478.33               1    100000.0
# 37505     3600.0    0.1240       120.27               1     50000.0
#
#        verification_status loan_status pymnt_plan    dti  delinq_2yrs  \
# index
# 67991                    0    low_risk          n  19.75          0.0
# 25429                    0    low_risk          n  11.52          2.0
# 38496                    0    low_risk          n   6.74          0.0
# 19667                    0    low_risk          n  12.13          0.0
# 37505                    0    low_risk          n  16.08          0.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  total_acc  \
# index
# ...

# %%
list(trained_df2['pymnt_plan'].unique())
# Out:
# ['n']

# %%
trained_df3 = trained_df2.drop(columns=["pymnt_plan"])
trained_df3
# Out:
#        loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# index
# 67991    40000.0    0.0819       814.70               0    140000.0
# 25429     6000.0    0.1524       208.70               1     55000.0
# 38496     3600.0    0.1695       128.27               1     42000.0
# 19667    20000.0    0.1524       478.33               1    100000.0
# 37505     3600.0    0.1240       120.27               1     50000.0
# ...          ...       ...          ...             ...         ...
# 77282    30000.0    0.1240       673.42               1    140480.0
# 77291    24000.0    0.0756       747.22               1     50000.0
# 77292    10000.0    0.2305       387.36               1     33000.0
# 77297     8000.0    0.1862       205.86               1     38000.0
# 77304    30000.0    0.2055      1123.34               1    180000.0
#
#        verification_status loan_status    dti  delinq_2yrs  inq_last_6mths  \
# index
# ...

# %%
list(trained_df3['initial_list_status'].unique())
# Out:
# ['w', 'f']

# %%
# encode string values to numeric values
list_status_dict = {'w': 0, 'f': 1}
trained_df4 = trained_df3.replace({'initial_list_status': list_status_dict})
trained_df4.head()
# Out:
#        loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# index
# 67991    40000.0    0.0819       814.70               0    140000.0
# 25429     6000.0    0.1524       208.70               1     55000.0
# 38496     3600.0    0.1695       128.27               1     42000.0
# 19667    20000.0    0.1524       478.33               1    100000.0
# 37505     3600.0    0.1240       120.27               1     50000.0
#
#        verification_status loan_status    dti  delinq_2yrs  inq_last_6mths  \
# index
# 67991                    0    low_risk  19.75          0.0             1.0
# 25429                    0    low_risk  11.52          2.0             0.0
# 38496                    0    low_risk   6.74          0.0             0.0
# 19667                    0    low_risk  12.13          0.0             2.0
# 37505                    0    low_risk  16.08          0.0             3.0
#
#        open_acc  pub_rec  revol_bal  total_acc  initial_list_status  \
# index
# ...

# %%
list(trained_df4['application_type'].unique())
# Out:
# ['Individual', 'Joint App']

# %%
# encode string values to numeric values
application_dict = {'Individual': 0, 'Joint App': 1}
trained_df5 = trained_df4.replace({'application_type': application_dict})
trained_df5.head()
# Out:
#        loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# index
# 67991    40000.0    0.0819       814.70               0    140000.0
# 25429     6000.0    0.1524       208.70               1     55000.0
# 38496     3600.0    0.1695       128.27               1     42000.0
# 19667    20000.0    0.1524       478.33               1    100000.0
# 37505     3600.0    0.1240       120.27               1     50000.0
#
#        verification_status loan_status    dti  delinq_2yrs  inq_last_6mths  \
# index
# 67991                    0    low_risk  19.75          0.0             1.0
# 25429                    0    low_risk  11.52          2.0             0.0
# 38496                    0    low_risk   6.74          0.0             0.0
# 19667                    0    low_risk  12.13          0.0             2.0
# 37505                    0    low_risk  16.08          0.0             3.0
#
#        open_acc  pub_rec  revol_bal  total_acc  initial_list_status  \
# index
# ...

# %%
list(trained_df5['hardship_flag'].unique())
# Out:
# ['N', 'Y']

# %%
# encode string values to numeric values
hardship_dict = {'N': 0, 'Y': 1}
trained_df6 = trained_df5.replace({'hardship_flag': hardship_dict})
trained_df6.head()
# Out:
#        loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# index
# 67991    40000.0    0.0819       814.70               0    140000.0
# 25429     6000.0    0.1524       208.70               1     55000.0
# 38496     3600.0    0.1695       128.27               1     42000.0
# 19667    20000.0    0.1524       478.33               1    100000.0
# 37505     3600.0    0.1240       120.27               1     50000.0
#
#        verification_status loan_status    dti  delinq_2yrs  inq_last_6mths  \
# index
# 67991                    0    low_risk  19.75          0.0             1.0
# 25429                    0    low_risk  11.52          2.0             0.0
# 38496                    0    low_risk   6.74          0.0             0.0
# 19667                    0    low_risk  12.13          0.0             2.0
# 37505                    0    low_risk  16.08          0.0             3.0
#
#        open_acc  pub_rec  revol_bal  total_acc  initial_list_status  \
# index
# ...

# %%
list(trained_df6['debt_settlement_flag'].unique())
# Out:
# ['N']

# %%
# encode string values to numeric values
debt_flag_dict = {'N': 0, 'Y': 1}
trained_df7 = trained_df6.replace({'debt_settlement_flag': debt_flag_dict})
trained_df7.head()
# Out:
#        loan_amnt  int_rate  installment  home_ownership  annual_inc  \
# index
# 67991    40000.0    0.0819       814.70               0    140000.0
# 25429     6000.0    0.1524       208.70               1     55000.0
# 38496     3600.0    0.1695       128.27               1     42000.0
# 19667    20000.0    0.1524       478.33               1    100000.0
# 37505     3600.0    0.1240       120.27               1     50000.0
#
#        verification_status loan_status    dti  delinq_2yrs  inq_last_6mths  \
# index
# 67991                    0    low_risk  19.75          0.0             1.0
# 25429                    0    low_risk  11.52          2.0             0.0
# 38496                    0    low_risk   6.74          0.0             0.0
# 19667                    0    low_risk  12.13          0.0             2.0
# 37505                    0    low_risk  16.08          0.0             3.0
#
#        open_acc  pub_rec  revol_bal  total_acc  initial_list_status  \
# index
# ...

# %%
# Drop the loan_status to create the X data
X = trained_df7.drop('loan_status', axis=1)
y = trained_df7['loan_status']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a logistic regression model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier

# %%
# Fit (train) our model by using the training data
classifier.fit(X_train, y_train)

# %%
# Validate the model by using the test data
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_true = y_test
y_pred = classifier.predict(X_test)
confusion_matrix(y_true, y_pred)

# %%
confusion_matrix(y, classifier.predict(X))

# %%
cl_report = classification_report(y_true, y_pred)
print(cl_report)

# %%
# Create and score a decision tree classifier
clf = DecisionTreeClassifier()

# %%
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')

# %%
# Identify all the possible values in the loan_status column
list(trained_df7['loan_status'].unique())
# Out:
# ['low_risk', 'high_risk']

# %%
#Now clean, read the diabetes dataset
X = trained_df7.drop('loan_status', axis=1)
y = trained_df7['loan_status']
target_names = ['low_risk', 'high_risk']

# %%
# Prepare the data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Import a Random Forests classifier
from sklearn.ensemble import RandomForestClassifier

# %%
# Fit a model, and then print a classification report
clf = RandomForestClassifier(random_state=1).fit(X_train_scaled, y_train)
y_pred = clf.predict(X_test_scaled)
print(classification_report(y_test, y_pred, target_names=target_names))
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
#               precision    recall  f1-score   support
#
#     low_risk       0.92      0.85      0.89       580
#    high_risk       0.87      0.93      0.90       596
#
#     accuracy                           0.89      1176
#    macro avg       0.89      0.89      0.89      1176
# weighted avg       0.89      0.89      0.89      1176
#
# Training Score: 1.0
# Testing Score: 0.8920068027210885

# %%
test_df.head()

# %%
# Convert categorical data to numeric and separate target feature for training data

# %%
# Convert categorical data to numeric and separate target feature for testing data

# %%
# add missing dummy variables to testing set

# %%
# Train the Logistic Regression model on the unscaled data and print the model score

# %%
# Train a Random Forest Classifier model and print the model score

# %%
# Scale the data

# %%
# Train the Logistic Regression model on the scaled data and print the model score

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
